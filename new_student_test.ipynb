# %%
import pandas as pd
import pytest
from my_functions import *
#pd.options.mode.chained_assignment = None  # default='warn'

# %%
x, y = load_data("data/student-mat.csv")
x
# Out:
#     school sex  age      Mjob      Fjob higher activities  G1  G2
# 0       GP   F   18   at_home   teacher    yes         no   5   6
# 1       GP   F   17   at_home     other    yes         no   5   5
# 2       GP   F   15   at_home     other    yes         no   7   8
# 3       GP   F   15    health  services    yes        yes  15  14
# 4       GP   F   16     other     other    yes         no   6  10
# ..     ...  ..  ...       ...       ...    ...        ...  ..  ..
# 390     MS   M   20  services  services    yes         no   9   9
# 391     MS   M   17  services  services    yes         no  14  16
# 392     MS   M   21     other     other    yes         no  10   8
# 393     MS   M   18  services     other    yes         no  11  12
# 394     MS   M   19     other   at_home    yes         no   8   9
#
# [395 rows x 9 columns]

# %%
lorenzo = new_student(x)
# Out:
# Please write the school of a student (['GP' 'MS']): GP
# Please write the sex of a student (['F' 'M']): F
# Please write the age of a student (from 15 to 25): 15
# Please write the Mjob of a student (['at_home' 'health' 'other' 'services' 'teacher']): at_home
# Please write the Fjob of a student (['teacher' 'other' 'services' 'health' 'at_home']): teacher
# Please write the higher of a student (['yes' 'no']): yes
# Please write the activities of a student (['no' 'yes']): yes
# Please write the G1 of a student (from 0 to 20): 20
# Please write the G2 of a student (from 0 to 20): 20

# %%
lorenzo
# Out:
#   school sex  age     Mjob     Fjob higher activities  G1  G2
# 0     GP   F   15  at_home  teacher    yes        yes  20  20

# %%
x_dummy = dummy_matrices(x)
# Out:
# C:\Users\Admin\Desktop\Project\my_functions.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_num[column] = non_num[column].apply(lambda x: column[0].lower() + "_" + x)

# %%
w, b, r_sq = compute_model(x_dummy,y)

# %%
w
b
r_sq
# Out:
# 0.8277567768920325

# %%
lorenzo
# Out:
# school         0
# sex            1
# age           25
# higher         1
# activities     1
# G1            20
# G2            20
# m_at_home      1
# m_health       0
# m_other        0
# m_services     0
# m_teacher      0
# f_at_home      0
# f_health       0
# f_other        1
# f_services     0
# f_teacher      0
# Name: 0, dtype: int64

# %%
x
# Out:
#     school sex  age      Mjob      Fjob higher activities  G1  G2
# 0       GP   F   18   at_home   teacher    yes         no   5   6
# 1       GP   F   17   at_home     other    yes         no   5   5
# 2       GP   F   15   at_home     other    yes         no   7   8
# 3       GP   F   15    health  services    yes        yes  15  14
# 4       GP   F   16     other     other    yes         no   6  10
# ..     ...  ..  ...       ...       ...    ...        ...  ..  ..
# 390     MS   M   20  services  services    yes         no   9   9
# 391     MS   M   17  services  services    yes         no  14  16
# 392     MS   M   21     other     other    yes         no  10   8
# 393     MS   M   18  services     other    yes         no  11  12
# 394     MS   M   19     other   at_home    yes         no   8   9
#
# [395 rows x 9 columns]

# %%
lorenzo = dummy_matrix_of_new_student(lorenzo, x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6516/1404712091.py in <module>
# ----> 1 lorenzo = dummy_matrix_of_new_student(lorenzo, x)
#
# ~\Desktop\Project\my_functions.py in dummy_matrix_of_new_student(new_student, x)
#     214
#     215     x_new = x.append(new_student)
# --> 216     new_dummy = dummy_matrices(x_new)
#     217     new_student_dummy = new_dummy.iloc[-1]
#     218
#
# ~\Desktop\Project\my_functions.py in dummy_matrices(data)
#      59
#      60         else:
# ---> 61             non_num[column] = non_num[column].apply(lambda x: column[0].lower() + "_" + x)
#      62             dummies = pd.get_dummies(non_num[column])
#      63             #dummies = dummies.drop([dummies.columns[-1]], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\Desktop\Project\my_functions.py in <lambda>(x)
#      59
#      60         else:
# ---> 61             non_num[column] = non_num[column].apply(lambda x: column[0].lower() + "_" + x)
#      62             dummies = pd.get_dummies(non_num[column])
#      63             #dummies = dummies.drop([dummies.columns[-1]], axis=1)
#
# TypeError: can only concatenate str (not "float") to str
