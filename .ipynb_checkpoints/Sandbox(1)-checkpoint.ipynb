# %%
from my_functions import *
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
def new_student(x):
    """
    
    Creates an array of features for a new student. 
    
    Parameters:
        x (pandas dataframe): Shape(m,n) Training set to the model. Defines the features for a new student
        
    Returns:
        new (pandas dataframe): 
    """
    
    new_data = {}
    for column in x.columns:
        if x[column].dtype == "object":
            inp = input("Please write the " + column + " of a student (" + str(x[column].unique()) + "): ")
            while inp not in x[column].unique():
                print("Invalid feature! Please try again!")
                inp = input("Please write the " + column + " of a student (" + str(x[column].unique()) + "): ")
                
        elif column == "age":
            while True:
                try:
                    inp = int(input("Please write the " + column +" of a student (from " + str(15) + " to " + str(25) + "): "))
                    while inp < 15 or inp > 25:
                        print("Invalid feature! Please try again!")
                        inp = int(input("Please write the " + column +" of a student (from " + str(15) + " to " + str(25) + "): "))
                except ValueError: 
                    print("Value Error for age! Please try again!")
                    continue
                
                if inp >= 15 or inp <= 25:
                    break
        
        
        elif column == "G1" or column == "G2":
            while True:
                try:
                    inp = int(input("Please write the " + column +" of a student (from " + str(0) + " to " + str(20) + "): "))
                    while inp < 0 or inp > 20:
                        print("Invalid grade! Please try again!")
                        inp = int(input("Please write the " + column +" of a student (from " + str(0) + " to " + str(20) + "): "))
                except ValueError:
                    print("Value Error for grade! Please try again!")
                    continue
                if inp >= 0 or inp <= 20:
                    break
                    
                    
        new_data[column] = inp
    
    df = pd.DataFrame(new_data, index=[0])
        
        
            
            
        
        
        
    return df

# %%
x, y = load_data("data/student-mat.csv")

# %%
x
# Out:
#     school sex  age      Mjob      Fjob higher activities  G1  G2
# 0       GP   F   18   at_home   teacher    yes         no   5   6
# 1       GP   F   17   at_home     other    yes         no   5   5
# 2       GP   F   15   at_home     other    yes         no   7   8
# 3       GP   F   15    health  services    yes        yes  15  14
# 4       GP   F   16     other     other    yes         no   6  10
# ..     ...  ..  ...       ...       ...    ...        ...  ..  ..
# 390     MS   M   20  services  services    yes         no   9   9
# 391     MS   M   17  services  services    yes         no  14  16
# 392     MS   M   21     other     other    yes         no  10   8
# 393     MS   M   18  services     other    yes         no  11  12
# 394     MS   M   19     other   at_home    yes         no   8   9
#
# [395 rows x 9 columns]

# %%
#print(x["school"].unique())
print("This is " + str(x["school"].unique()))
# Out:
# This is ['GP' 'MS']

# %%
    for column in x.columns:
        if x[column].dtype == "object":
            inp = input("Please write the " + column + " of a student (" + str(x[column].unique()) + "): ")
            while inp not in x[column].unique():
                print("Invalid feature! Please try again!")
                inp = input("Please write the " + column + " of a student (" + str(x[column].unique()) + "): ")
        elif column == "age":
            while True:
                try:
                    inp = int(input("Please write the " + column +" of a student (from " + str(15) + " to " + str(25) + "): "))
                    while inp < 15 or inp > 25:
                        print("Invalid feature! Please try again!")
                        inp = int(input("Please write the " + column +" of a student (from " + str(15) + " to " + str(25) + "): "))
                except ValueError: 
                    print("Value Error!")
                    continue
                
                if inp >= 15 or inp <= 25:
                    break
# Out:
# Please write the school of a student (['GP' 'MS']): GP
# Please write the sex of a student (['F' 'M']): F
# Please write the age of a student (from 15 to 25): sad
# Value Error!
# Please write the age of a student (from 15 to 25): sad
# Value Error!
# Please write the age of a student (from 15 to 25): sad
# Value Error!
# Please write the age of a student (from 15 to 25): sa
# Value Error!
# Please write the age of a student (from 15 to 25): d
# Value Error!
# Please write the age of a student (from 15 to 25): sd
# Value Error!
# Please write the age of a student (from 15 to 25): 30
# Invalid feature! Please try again!
# Please write the age of a student (from 15 to 25): 15
# Please write the Mjob of a student (['at_home' 'health' 'other' 'services' 'teacher']): adsf
# Invalid feature! Please try again!
# Please write the Mjob of a student (['at_home' 'health' 'other' 'services' 'teacher']): at_home
# Please write the Fjob of a student (['teacher' 'other' 'services' 'health' 'at_home']): other
# Please write the higher of a student (['yes' 'no']): yes
# Please write the activities of a student (['no' 'yes']): yes

# %%
for column in x.columns:
    if x[column].dtype == "object":
        #print(x[column].unique())
        inp = input("Please write the " + column + " of a student (" + str(x[column].unique()) + "): ")
        while inp not in x[column].unique():
            print("Invalid feature! Please try again!")
            inp = input("Please write the " + column + " of a student (" + str(x[column].unique()) + "): ")
    elif column == "age":
            try:
                inp = int(input("Please write the " + column +" of a student (from " + str(15) + " to " + str(25) + "): "))
                while inp < 15 or inp > 25: 
                    print("Number is too low or too high! Please try again!")
                    inp = int(input("Please write the " + column +" of a student (from " + str(15) + " to " + str(25) + "): "))
            except ValueError:
                while True:
                    print("Value")
                    inp = int(input("Please write the " + column +" of a student (from " + str(15) + " to " + str(25) + "): "))
                    if inp >=15 or inp <= 25:
                        break
# Out:
# Please write the school of a student (['GP' 'MS']): GP
# Please write the sex of a student (['F' 'M']): F
# Please write the age of a student (from 15 to 25): 10
# Number is too low or too high! Please try again!
# Please write the age of a student (from 15 to 25): 30
# Number is too low or too high! Please try again!
# Please write the age of a student (from 15 to 25): sad
# Value
# Please write the age of a student (from 15 to 25): adsa
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9428/1391845812.py in <module>
#      12                     print("Number is too low or too high! Please try again!")
# ---> 13                     inp = int(input("Please write the " + column +" of a student (from " + str(15) + " to " + str(25) + "): "))
#      14             except ValueError:
#
# ValueError: invalid literal for int() with base 10: 'sad'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9428/1391845812.py in <module>
#      15                 while True:
#      16                     print("Value")
# ---> 17                     inp = int(input("Please write the " + column +" of a student (from " + str(15) + " to " + str(25) + "): "))
#      18                     if inp >=15 or inp <= 25:
#      19                         break
#
# ValueError: invalid literal for int() with base 10: 'adsa'

# %%
new_example = new_student(x)
# Out:
# Please write the school of a student (['GP' 'MS']): MS
# Please write the sex of a student (['F' 'M']): F
# Please write the age of a student (from 15 to 25): sad
# Value Error for age! Please try again!
# Please write the age of a student (from 15 to 25): 20
# Please write the Mjob of a student (['at_home' 'health' 'other' 'services' 'teacher']): health
# Please write the Fjob of a student (['teacher' 'other' 'services' 'health' 'at_home']): services
# Please write the higher of a student (['yes' 'no']): yes
# Please write the activities of a student (['no' 'yes']): yes
# Please write the G1 of a student (from 0 to 20): sad
# Value Error for grade! Please try again!
# Please write the G1 of a student (from 0 to 20): a
# Value Error for grade! Please try again!
# Please write the G1 of a student (from 0 to 20): 20
# Please write the G2 of a student (from 0 to 20): 20

# %%
new_example
# Out:
#   school sex  age    Mjob      Fjob higher activities  G1  G2
# 0     MS   F   20  health  services    yes        yes  20  20

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9428/3973081903.py in <module>
# ----> 1 new_stud = pd.DataFrame(new_example, columns = x.columns)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     709                     )
#     710                 else:
# --> 711                     mgr = ndarray_to_mgr(
#     712                         data,
#     713                         index,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _check_values_indices_shape_match(values, index, columns)
#     391         passed = values.shape
#     392         implied = (len(index), len(columns))
# --> 393         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     394
#     395
#
# ValueError: Shape of passed values is (9, 1), indices imply (9, 9)

# %%
type(1)
# Out:
# int
